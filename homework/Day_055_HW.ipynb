# %% [markdown]
# # 作業
#
# - 作業目標 : iris (dataset.load_iris()) 資料嘗試跑 kmeans (可以測試不同的群數 , init 等)

# %%
import numpy as np
import pandas as pd
from sklearn import datasets
from sklearn.preprocessing import scale

# %matplotlib inline

iris = datasets.load_iris()
x = scale(iris.data)
y = pd.DataFrame(iris.target)

# %% [markdown]
# ### 載入 相關套件 並 執行 kmean 實驗 ...
#
# - 實驗測試不同的群數
# - 實驗測試不同的初始值
# - 呈現結果

# %%
from sklearn.cluster import KMeans

# %%
variable_names = iris.feature_names
variable_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
clustering_n3 = KMeans(n_clusters=3, random_state=5)
clustering_n3.fit(x)

clustering_n5 = KMeans(n_clusters=5, random_state=5)
clustering_n5.fit(x)

clustering_init = KMeans(n_clusters=3, random_state=5, n_init=1, init='random')
clustering_init.fit(x)

iris_df = pd.DataFrame(iris.data)
iris_df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width']
y.columns = ['Target']

# %%
clustering
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=5, tol=0.0001, verbose=0)

# %%
colors = np.array(['Red', 'Green', 'Blue', 'Black', 'Pink'])
plt.subplot(2, 2, 1)
plt.scatter(x=iris_df['petal_length'], y=iris_df['petal_width'], c=colors[iris.target], s=20)
plt.title('Before K-Means')

plt.subplot(2, 2, 2)
plt.scatter(x=iris_df['petal_length'], y=iris_df['petal_width'], c=colors[clustering_n3.labels_], s=20)
plt.title('K-Means')

plt.subplot(2, 2, 3)
plt.scatter(x=iris_df['petal_length'], y=iris_df['petal_width'], c=colors[clustering_init.labels_], s=20)

plt.subplot(2, 2, 4)
plt.scatter(x=iris_df['petal_length'], y=iris_df['petal_width'], c=colors[clustering_n5.labels_], s=20)

# %%
colors = np.array(['Red', 'Green', 'Blue', 'Black', 'Pink'])
plt.subplot(2, 2, 1)
plt.scatter(x=iris_df['sepal_length'], y=iris_df['sepal_width'], c=colors[iris.target], s=20)
plt.title('Before K-Means')

plt.subplot(2, 2, 2)
plt.scatter(x=iris_df['sepal_length'], y=iris_df['sepal_width'], c=colors[clustering_n3.labels_], s=20)
plt.title('K-Means')

plt.subplot(2, 2, 3)
plt.scatter(x=iris_df['sepal_length'], y=iris_df['sepal_width'], c=colors[clustering_init.labels_], s=20)

plt.subplot(2, 2, 4)
plt.scatter(x=iris_df['sepal_length'], y=iris_df['sepal_width'], c=colors[clustering_n5.labels_], s=20)
